# %%
# %run pyoptionprofit.ipynb

# %%
# NFLX
gains, legs, net_cost = compute_strategy(
    date_start = datetime(2020, 5, 22),
    date_end = datetime(2020, 6, 19),
    price_lower = 35,
    price_upper = 55,
    price_step = 1,
    strategy = [
        long_put(underlying_price=44.35,
                  strike_price=43,
                  expires_on=datetime(2020,6,19),
                  contract_ask=4.2,
                  contract_bid=3.75,
                  n_contracts=1)]
)

# %%
net_cost
# Out:
# 420.0

# %%
graph_result(gains, net_cost, pct=False)

# %%
gains
# Out:
# Empty DataFrame
# Columns: [2020-05-21 00:00:00, 2020-05-22 00:00:00, 2020-05-23 00:00:00, 2020-05-24 00:00:00, 2020-05-25 00:00:00, 2020-05-26 00:00:00, 2020-05-27 00:00:00, 2020-05-28 00:00:00, 2020-05-29 00:00:00, 2020-05-30 00:00:00, 2020-05-31 00:00:00, 2020-06-01 00:00:00, 2020-06-02 00:00:00, 2020-06-03 00:00:00, 2020-06-04 00:00:00, 2020-06-05 00:00:00, 2020-06-06 00:00:00, 2020-06-07 00:00:00, 2020-06-08 00:00:00, 2020-06-09 00:00:00, 2020-06-10 00:00:00, 2020-06-11 00:00:00, 2020-06-12 00:00:00, 2020-06-13 00:00:00, 2020-06-14 00:00:00, 2020-06-15 00:00:00, 2020-06-16 00:00:00, 2020-06-17 00:00:00, 2020-06-18 00:00:00, 2020-06-19 00:00:00, 2020-06-20 00:00:00, 2020-06-21 00:00:00, 2020-06-22 00:00:00, 2020-06-23 00:00:00, 2020-06-24 00:00:00, 2020-06-26 00:00:00]
# Index: []
#
# [0 rows x 36 columns]
