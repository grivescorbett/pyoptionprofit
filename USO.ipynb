# %%
# %run pyoptionprofit.ipynb

# %%
# NFLX
gains, legs, net_cost = compute_strategy(
    date_start = datetime(2020, 5, 21),
    date_end = datetime(2020, 6, 5),
    day_ticks = 10,
    price_lower = 26-10,
    price_upper = 26+10,
    price_step = 1,
    strategy = [
        long_put(underlying_price=26.74,
                  strike_price=25,
                  expires_on=datetime(2020,6,5),
                  contract_ask=0.93,
                  contract_bid=0.91,
                  n_contracts=2)]
)

# %%
net_cost
# Out:
# 186.0

# %%
graph_result(gains, net_cost, pct=True)

# %%
gains
# Out:
#      2020-05-21   2020-05-22   2020-05-24   2020-05-26   2020-05-27  \
# 20   514.907562   512.959479   509.270052   505.957444   504.491005
# 19   606.846490   605.684093   603.607240   601.925572   601.257850
# 18   702.528759   701.933821   700.952866   700.268399   700.039352
# 17   800.490889   800.245749   799.890729   799.705045   799.667438
# 16   899.662177   899.597988   899.537877   899.551811   899.578808
# 15   999.379558   999.392117   999.443757   999.519759   999.563024
# 14  1099.301347  1099.339796  1099.424401  1099.514847  1099.561033
# 13  1199.284481  1199.329613  1199.421482  1199.514327  1199.560866
# 12  1299.281788  1299.328176  1299.421179  1299.514291  1299.560857
# 11  1399.281489  1399.328039  1399.421159  1399.514290  1399.560857
# 10  1499.281468  1499.328031  1499.421158  1499.514290  1499.560857
#
#      2020-05-29   2020-05-31   2020-06-01   2020-06-03  2020-06-05
# 20   502.062609   500.493366   500.082477   499.890907      499.98
# ...
